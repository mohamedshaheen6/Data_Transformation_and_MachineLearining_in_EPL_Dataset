# %%
import pandas as pd
import numpy as np

# %%
epl=pd.read_csv("C:/Users/ASUS/Desktop/DS SM/ML/Project/eplmatches.csv")
epl
# Out:
#        Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals  \
# 0                 1993   1  1992-08-15   Coventry City          2          1
# 1                 1993   1  1992-08-15    Leeds United          2          1
# 2                 1993   1  1992-08-15   Sheffield Utd          2          1
# 3                 1993   1  1992-08-15  Crystal Palace          3          3
# 4                 1993   1  1992-08-15         Arsenal          2          4
# ...                ...  ..         ...             ...        ...        ...
# 11641             2022   9  2021-10-23    Leeds United          1          1
# 11642             2022   9  2021-10-23        Brighton          1          4
# 11643             2022   9  2021-10-24        West Ham          1          0
# 11644             2022   9  2021-10-24       Brentford          1          2
# 11645             2022   9  2021-10-24  Manchester Utd          0          5
#
#                   Away FTR
# ...

# %%
away=epl.iloc[:,[6,5]]
away
# Out:
#                   Away  AwayGoals
# 0        Middlesbrough          1
# 1            Wimbledon          1
# 2       Manchester Utd          1
# 3            Blackburn          3
# 4         Norwich City          4
# ...                ...        ...
# 11641           Wolves          1
# 11642  Manchester City          4
# 11643        Tottenham          0
# 11644   Leicester City          2
# 11645        Liverpool          5
#
# [11646 rows x 2 columns]

# %%
a=away.groupby(away.Away).sum()
a
# Out:
#                  AwayGoals
# Away
# Arsenal                863
# Aston Villa            581
# Barnsley                12
# Birmingham City        111
# Blackburn              382
# Blackpool               25
# Bolton                 256
# Bournemouth            105
# Bradford City           22
# Brentford               26
# Brighton                86
# Burnley                139
# Cardiff City            25
# Charlton Ath           143
# Chelsea                852
# Coventry City          168
# Crystal Palace         276
# Derby County           114
# Everton                610
# Fulham                 251
# Huddersfield            24
# Hull City               74
# Ipswich Town            94
# Leeds United           341
# Leicester City         385
# Liverpool              865
# Manchester City        701
# Manchester Utd         971
# Middlesbrough          255
# Newcastle Utd          546
# Norwich City           174
# Nott'ham Forest        114
# Oldham Athletic         38
# ...

# %%
#clubs who scored most away goals
a.sort_values(by='AwayGoals',ascending=False)
# Out:
#                  AwayGoals
# Away
# Manchester Utd         971
# Liverpool              865
# Arsenal                863
# Chelsea                852
# Tottenham              750
# Manchester City        701
# Everton                610
# Aston Villa            581
# Newcastle Utd          546
# West Ham               505
# Southampton            450
# Leicester City         385
# Blackburn              382
# Leeds United           341
# Crystal Palace         276
# Sunderland             276
# Bolton                 256
# Middlesbrough          255
# Fulham                 251
# West Brom              215
# Sheffield Weds         175
# Norwich City           174
# Coventry City          168
# Wimbledon              166
# Stoke City             150
# Wigan Athletic         147
# Wolves                 147
# QPR                    145
# Charlton Ath           143
# Burnley                139
# Watford                130
# Swansea City           127
# Nott'ham Forest        114
# ...

# %%
awaycon=epl.iloc[:,[6,4]]
awaycon
# Out:
#                   Away  HomeGoals
# 0        Middlesbrough          2
# 1            Wimbledon          2
# 2       Manchester Utd          2
# 3            Blackburn          3
# 4         Norwich City          2
# ...                ...        ...
# 11641           Wolves          1
# 11642  Manchester City          1
# 11643        Tottenham          1
# 11644   Leicester City          1
# 11645        Liverpool          0
#
# [11646 rows x 2 columns]

# %%
c=awaycon.groupby(awaycon.Away).sum()
c
# Out:
#                  HomeGoals
# Away
# Arsenal                659
# Aston Villa            776
# Barnsley                47
# Birmingham City        220
# Blackburn              526
# Blackpool               41
# Bolton                 432
# Bournemouth            182
# Bradford City           80
# Brentford               35
# Brighton               133
# Burnley                260
# Cardiff City            70
# Charlton Ath           244
# Chelsea                640
# Coventry City          291
# Crystal Palace         403
# Derby County           243
# Everton                841
# Fulham                 468
# Huddersfield            78
# Hull City              178
# Ipswich Town           185
# Leeds United           416
# Leicester City         479
# Liverpool              689
# Manchester City        610
# Manchester Utd         638
# Middlesbrough          439
# Newcastle Utd          826
# Norwich City           390
# Nott'ham Forest        169
# Oldham Athletic         79
# ...

# %%
#Clubs monceded most away goals
c.sort_values(by='HomeGoals',ascending=False)
# Out:
#                  HomeGoals
# Away
# Everton                841
# Newcastle Utd          826
# Tottenham              820
# West Ham               794
# Aston Villa            776
# Southampton            740
# Liverpool              689
# Arsenal                659
# Chelsea                640
# Manchester Utd         638
# Manchester City        610
# Sunderland             533
# Blackburn              526
# Leicester City         479
# Fulham                 468
# Middlesbrough          439
# Bolton                 432
# Leeds United           416
# West Brom              411
# Crystal Palace         403
# Norwich City           390
# Stoke City             312
# Coventry City          291
# Watford                282
# Wimbledon              274
# Wigan Athletic         267
# Sheffield Weds         266
# Burnley                260
# Charlton Ath           244
# Derby County           243
# Wolves                 242
# QPR                    241
# Portsmouth             221
# ...
